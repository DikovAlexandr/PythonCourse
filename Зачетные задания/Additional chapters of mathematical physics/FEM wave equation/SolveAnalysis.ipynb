# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math

# %%
X = np.arange(0, 1.05, 0.05)
Xdim = len(X)
T = np.arange(0, 1.05, 0.05)
Tdim = len(T)
U = np.loadtxt("solve.csv")
print(U)
# Out:
# [[ 0.0000000e+00  1.2489594e-01  2.4916999e-01  3.7221258e-01
#    4.9343830e-01  6.1229666e-01  7.2828153e-01  8.4093886e-01
#    9.4987241e-01  1.0547475e+00  1.1552929e+00  1.2513005e+00
#    1.3426239e+00  1.4291749e+00  1.5109194e+00  1.5878724e+00
#    1.6600919e+00  1.7276737e+00  1.7907447e+00  1.8494576e+00
#    1.9039854e+00]
#  [-1.2500000e-01  2.0791730e-04  1.2541170e-01  2.4998343e-01
#    3.7330793e-01  4.9479480e-01  6.1388941e-01  7.3008242e-01
#    8.4291756e-01  9.5199736e-01  1.0569869e+00  1.1576156e+00
#    1.2536767e+00  1.3450257e+00  1.4315770e+00  1.5132992e+00
#    1.5902100e+00  1.6623708e+00  1.7298800e+00  1.7928675e+00
#    1.8514886e+00]
#  [-2.4832402e-01 -1.2448114e-01  1.1839396e-03  1.2682573e-01
#    2.5180824e-01  3.7550934e-01  4.9733297e-01  6.1672032e-01
#    7.3315941e-01  8.4619278e-01  9.5542322e-01  1.0605173e+00
#    1.1612069e+00  1.2572887e+00  1.3486220e+00  1.4351255e+00
#    1.5167724e+00  1.5935848e+00  1.6656285e+00  1.7330059e+00
# ...

# %%
Uanalytic = np.array([[5/ 2 * np.tanh(x - t) for x in X] for t in T])

# %%
plt.plot(T, U[8], label='FEM')
plt.plot(T, Uanalytic[8], label='Analytic')
plt.legend()
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, T, U, cmap='ocean')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, T, Uanalitic, cmap='ocean')
plt.show()
